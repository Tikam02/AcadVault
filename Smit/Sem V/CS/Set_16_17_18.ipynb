# %% [markdown]
# <a href="https://colab.research.google.com/github/nishi1612/SC374-Computational-and-Numerical-Methods/blob/master/Set_16_17_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

def f(x,y):
  return -y + 2*math.cos(x)

init_x = 0
init_y = 1

hrange = [0.1,0.2,0.05]
y_values = []
x_values = []
for h in hrange:
  xrange = np.arange(0,10,h)
  y = init_y
  ans_y = []
  ans_y.append(y)
  for x in xrange:
    v1 = f(x,y)
    v2 = f(x + h/2 , y + h*v1/2)
    v3 = f(x + h/2 , y + h*v2/2)
    v4 = f(x + h , y + h*v3)
    y = y + h* (v1 + 2*v2 + 2*v3 + v4)/6 
    ans_y.append(y)
  x_values.append(xrange)
  y_values.append(ans_y[:-1])

def func(h,x,y0):
  y = np.zeros(len(x))
  y[0] = y0
  for i in range(1,len(x)):
    y[i] = y[i-1] + (h*(f(x[i-1],y[i-1]) + f(x[i],y[i-1] + h*f(x[i-1],y[i-1])))/ 2)
  return y

k =0
for h in hrange:
  ans_y = []
  ans_y = func(h,x_values[k],init_y)
  x_values.append(x_values[k])
  y_values.append(ans_y)
  k = k+1

for i in range(3):
  j = i
  plt.plot(x_values[i],y_values[i],color='blue',label="Fourth order")
  plt.plot(x_values[i+3],y_values[i+3],color='green',label="Second order")
#   plt.plot(x_values[i],np.sin(x_values[i])+np.cos(x_values[i]),color='red',label="$y = sinx + cosx$")
  plt.legend(loc="upper right")
  plt.title("Value of h is " + str(hrange[i]))
  plt.xlabel('$x$')
  plt.ylabel('$y$')
  plt.show()
  plt.plot(x_values[i],np.sin(x_values[i])+np.cos(x_values[i]) - y_values[i],label="Fourth order")
  plt.plot(x_values[i],np.sin(x_values[i])+np.cos(x_values[i]) - y_values[i+3],label="Second order")
  plt.legend(loc="upper right")
  plt.xlabel('$x$')
  plt.ylabel('Error')
  plt.title("Error v/s x \n Value of h is " + str(hrange[i]))
  plt.show()

# %%
def f(x,y):
  return -y + x**(0.1)*(1.1+x)

init_x = 0
init_y = 0

hrange = [0.1,0.05,0.025,0.0125,0.00625]
y_values = []
x_values = []
for h in hrange:
  xrange = np.arange(0,5,h)
  y = init_y
  ans_y = []
  ans_y.append(y)
  for x in xrange:
    v1 = f(x,y)
    v2 = f(x + h/2 , y + h*v1/2)
    v3 = f(x + h/2 , y + h*v2/2)
    v4 = f(x + h , y + h*v3)
    y = y + h* (v1 + 2*v2 + 2*v3 + v4)/6 
    ans_y.append(y)
  x_values.append(xrange)
  y_values.append(ans_y[:-1])

def func(h,x,y0):
  y = np.zeros(len(x))
  y[0] = y0
  for i in range(1,len(x)):
    y[i] = y[i-1] + (h*(f(x[i-1],y[i-1]) + f(x[i],y[i-1] + h*f(x[i-1],y[i-1])))/ 2)
  return y

k =0
for h in hrange:
  ans_y = []
  ans_y = func(h,x_values[k],init_y)
  x_values.append(x_values[k])
  y_values.append(ans_y)
  k = k+1

for i in range(5):
  j = i
  plt.plot(x_values[i],y_values[i],color='blue',label="Fourth order")
  plt.plot(x_values[i+5],y_values[i+5],color='green',label="Second order")
#  plt.plot(x_values[i],np.sin(x_values[i])+np.cos(x_values[i]),color='red',label="$y = sinx + cosx$")
  plt.legend(loc="upper right")
  plt.title("Value of h is " + str(hrange[i]))
  plt.xlabel('$x$')
  plt.ylabel('$y$')
  plt.show()
  plt.plot(x_values[i],x_values[i]**1.1 - y_values[i],label="Fourth order")
  plt.plot(x_values[i],x_values[i]**1.1 - y_values[i+5],label="Second order")
  plt.legend(loc="upper right")
  plt.xlabel('$x$')
  plt.ylabel('Error')
  plt.title("Error v/s x \n Value of h is " + str(hrange[i]))
  plt.show()

# %% [markdown]
# **Lab 17**

# %%
A = 4
B = 0.5
C = 3
D = 1/3

def f1(x,y1,y2):
  return A*y1*(1-B*y2)

def f2(x,y1,y2):
  return C*y2*(D*y1-1)

hrange = [0.01,0.005]

y1_values = []
y2_values = []
x_values = []

y1_init = 3
y2_init = 5
x_init = 0

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,4,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y1_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y1$')
plt.title('Value of $y1$')
plt.show()
plt.plot(x_values[0],y2_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y2_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y2$')
plt.title('Value of $y2$')
plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.plot(y1_values[1],y2_values[1],color='green')
plt.title('$Y2$ v/s $Y1$')
plt.xlabel('$Y1$')
plt.ylabel('$Y2$')
plt.show()

# %%
y1_init = 3
y2_init = 1
x_init = 0

y1_values = []
y2_values = []
x_values = []

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,4,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y1_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y1$')
plt.title('Value of $y1$')
plt.show()
plt.plot(x_values[0],y2_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y2_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y2$')
plt.title('Value of $y2$')
plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.plot(y1_values[1],y2_values[1],color='green')
plt.title('$Y2$ v/s $Y1$')
plt.xlabel('$Y1$')
plt.ylabel('$Y2$')
plt.show()

# %%
y1_init = 3
y2_init = 1.5
x_init = 0

y1_values = []
y2_values = []
x_values = []

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,4,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y1_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y1$')
plt.title('Value of $y1$')
plt.show()
plt.plot(x_values[0],y2_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y2_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y2$')
plt.title('Value of $y2$')
plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.plot(y1_values[1],y2_values[1],color='green')
plt.title('$Y2$ v/s $Y1$')
plt.xlabel('$Y1$')
plt.ylabel('$Y2$')
plt.show()

# %%
y1_init = 3
y2_init = 1.9
x_init = 0

y1_values = []
y2_values = []
x_values = []

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,4,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y1_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y1$')
plt.title('Value of $y1$')
plt.show()
plt.plot(x_values[0],y2_values[0],color='blue',label="h = 0.01")
plt.plot(x_values[1],y2_values[1],color='green',label="h = 0.005")
plt.legend(loc="upper right")
plt.xlabel('$x$')
plt.ylabel('$y2$')
plt.title('Value of $y2$')
plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.plot(y1_values[1],y2_values[1],color='green')
plt.title('$Y2$ v/s $Y1$')
plt.xlabel('$Y1$')
plt.ylabel('$Y2$')
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

def twobvp(p,q,r,x1,x2,h,yx1,yx2):
    xvals = np.arange(x1,x2 + h,h)
    N = xvals.size - 1
    
    A = np.zeros((N-1,N-1))
    B = np.zeros((N-1,1))
    
    A[0][0] = (2 + (h**2)*q(xvals[1]))
    A[0][1] = ((h/2)*p(xvals[1])) - 1
    B[0] = (-h**2)*r(xvals[1]) + (1 + (h/2)*p(xvals[1]))*yx1
    
    svals = 0
    
    for i in range(1,N-2):
        A[i][svals] = -(1+(h/2)*p(xvals[i]))
        A[i][svals+1] = (2+(h**2)*q(xvals[i]))
        A[i][svals+2] = (h/2)*p(xvals[i]) - 1
        B[i] = (-h**2)*r(xvals[i+1])
        
        svals += 1
        
    A[N-2][N-3] = -(1 + (h/2)*p(xvals[N-1]))
    A[N-2][N-2] = 2 + (h**2)*q(xvals[N-1])
    B[N-2] = -(h**2)*r(xvals[N-1]) - ((h/2)*p(xvals[N-1]) - 1)*yx2
    
    t = np.linalg.inv(A)@B
    
    y = np.zeros(N+1,dtype = float)
    y[0] = yx1
    y[-1] = yx2
    y[1:-1] = t.reshape(N-1,)
    
    return y

def p(x):
    return (-2*x)/(1+x**2)

def q(x):
    return 1

def r(x):
    return 2/(1+x**2) - np.log(1+x**2)
  
x1 = 0
x2 = 1
yx1 = 0
yx2 = np.log(2)
h = 1/40

yvals = twobvp(p,q,r,x1,x2,h,yx1,yx2)

x = np.arange(x1,x2+h,h)
plt.plot(np.arange(x1,x2 + h,h),yvals,color='blue',label='Two Point Boundary Value Problem')
plt.plot(np.arange(x1,x2+h,h),np.log(1 + x**2),color='green',label='$y = ln(1+x^2)$')
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.legend()
plt.title("$x$ v/s $y$")
plt.show()

plt.plot(x,np.log(1 + x**2)-yvals,color='blue')
plt.title("Error v/s $x$")
plt.ylabel("Error")
plt.xlabel("$x$")
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

A = 0.03
B = 0.03
C = 1
D = -1
e = 0

def f1(x,y1,y2):
  return y2

def f2(x,y1,y2):
  return -1*e*(A*y1 + B*y2)*y2 - (C*y1 + e*D*((y1)**2))

hrange = [0.0001]

y1_values = []
y2_values = []
x_values = []

y1_init = 0.95
y2_init = 0
x_init = 0

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,10,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\phi$')
plt.title('Value of $y1$')
plt.show()

plt.plot(x_values[0],y2_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\psi$')
plt.title('Value of $y2$')

temp1 = y1_values[0]
temp2 = y2_values[0]

plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.title('$\psi$ v/s $\phi$')
plt.xlabel('$\phi$')
plt.ylabel('$\psi$')
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

A = 0.03
B = 0.03
C = 1
D = -1
e = 1

def f1(x,y1,y2):
  return y2

def f2(x,y1,y2):
  return -1*e*(A*y1 + B*y2)*y2 - (C*y1 + e*D*((y1)**2))

hrange = [0.0001]

y1_values = []
y2_values = []
x_values = []

y1_init = 0.95
y2_init = 0
x_init = 0

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,30,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\phi$')
plt.title('Value of $y1$')
plt.show()

plt.plot(x_values[0],y2_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\psi$')
plt.title('Value of $y2$')

temp3 = y1_values[0]
temp4 = y2_values[0]

plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.title('$\psi$ v/s $\phi$')
plt.xlabel('$\phi$')
plt.ylabel('$\psi$')
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

A = 0.03
B = 0.03
C = 1
D = -1
e = 0

def f1(x,y1,y2):
  return y2

def f2(x,y1,y2):
  return -1*e*(A*y1 + B*y2)*y2 - (C*y1 + e*D*((y1)**2))

hrange = [0.0001]

y1_values = []
y2_values = []
x_values = []

y1_init = 1.05
y2_init = 0
x_init = 0

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,10,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\phi$')
plt.title('Value of $y1$')
plt.show()

plt.plot(x_values[0],y2_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\psi$')
plt.title('Value of $y2$')

temp5 = y1_values[0]
temp6 = y2_values[0]

plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.title('$\psi$ v/s $\phi$')
plt.xlabel('$\phi$')
plt.ylabel('$\psi$')
plt.show()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

A = 0.03
B = 0.03
C = 1
D = -1
e = 1

def f1(x,y1,y2):
  return y2

def f2(x,y1,y2):
  return round(-1*e*(A*y1 + B*y2)*y2,3) - round((C*y1 + round(e*D*((y1)**2),3)),3)

hrange = [0.001]

y1_values = []
y2_values = []
x_values = []

y1_init = 1.05
y2_init = 0
x_init = 0

for h in hrange:
  ans_y1 = []
  ans_y2 = []
  y1 = y1_init
  y2 = y2_init
  ans_y1.append(y1)
  ans_y2.append(y2)
  xrange = np.arange(0,3,h)
  for x in xrange:
    v11 = f1(x,y1,y2)
    v12 = f2(x,y1,y2)
    
    v21 = f1(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    v22 = f2(x + h/2 , y1 + h*v11/2 , y2 + h*v12/2)
    
    v31 = f1(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
    v32 = f2(x + h/2 , y1 + h*v21/2 , y2 + h*v22/2)
 
    v41 = f1(x + h , y1 + h*v31 ,  y2 + h*v32)
    v42 = f2(x + h , y1 + h*v31 ,  y2 + h*v32)
    
    y1 = y1 + h* (v11 + 2*v21 + 2*v31 + v41)/6 
    y2 = y2 + h* (v12 + 2*v22 + 2*v32 + v42)/6 
    
    ans_y1.append(y1)
    ans_y2.append(y2)
  y1_values.append(ans_y1[:-1])
  y2_values.append(ans_y2[:-1])
  x_values.append(xrange)
  
plt.plot(x_values[0],y1_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\phi$')
plt.title('Value of $y1$')
plt.show()

plt.plot(x_values[0],y2_values[0],color='blue')
plt.xlabel('$x$')
plt.ylabel('$\psi$')
plt.title('Value of $y2$')

temp7 = y1_values[0]
temp8 = y2_values[0]

plt.show()
plt.plot(y1_values[0],y2_values[0],color='blue')
plt.title('$\psi$ v/s $\phi$')
plt.xlabel('$\phi$')
plt.ylabel('$\psi$')
plt.show()

# %%
plt.plot(temp1,temp2,color='blue',label='$\epsilon$ = 0 , (0.95,0)')
plt.plot(temp3,temp4,color='green',label='$\epsilon$ = 1 , (0.95,0)')
plt.plot(temp5,temp6,color='black',label='$\epsilon$ = 0 , (1.05,0)')
plt.plot(temp7,temp8,color='red',label='$\epsilon$ = 1 , (1.05,0)')
plt.legend()
plt.title('$\psi$ v/s $\phi$')
plt.xlabel('$\phi$')
plt.ylabel('$\psi$')
plt.show()
