# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
fun = lambda x:x+ 2*np.sin(1.5*x)
k = 1500

x = np.arange(1, (2*np.pi*k)/(1.5*1000), 0.01)
y = fun(x)

# %%
noise = norm(loc = 0., scale = 2.0)
a = r.pdf(np.linspace(-5,5,x.shape[0]))
plt.plot(np.linspace(-5,5,x.shape[0]), a)
plt.grid()

plt.figure(2)
plt.plot(x,a+y)
plt.plot(x,y,'black')
plt.grid()

# %% [markdown]
# # Bias-Variance for Linear Hypothesis

# %%
from sklearn.linear_model import Linear Regression
