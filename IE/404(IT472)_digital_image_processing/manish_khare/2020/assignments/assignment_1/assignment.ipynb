# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('download.jpeg')
img2 = cv2.imread('download_grey.jpeg')

# %%
plt.imshow(img)
plt.show()
plt.imshow(img2, cmap='gray')
plt.show()

# %%
# Out:
# True
